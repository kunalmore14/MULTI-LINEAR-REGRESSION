# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\ayush\Downloads\salary dataset.csv")
data.head(3)
# Out:
#    Age  Experience  Salary
# 0   21           1   39343
# 1   22           1   46205
# 2   22           2   37731

# %%
data.shape
# Out:
# (30, 3)

# %%
data.isnull().sum()
# Out:
# Age           0
# Experience    0
# Salary        0
# dtype: int64

# %%
sns.pairplot(data=data)
plt.show()
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(data=data.corr(),annot=True)
plt.show()

# %%
x = data.iloc[:,:-1]
y = data['Salary']

# %%
x.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (30, 3)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 84.00806738900366

# %%
lr.coef_
# Out:
# array([3332.82459147, 3433.54778796])

# %%
lr.intercept_
# Out:
# -34082.50023913903

# %%
#y = m1x1 + m2x2 + c

# %%
#y_pred = 3332.82459147*Age + 3433.54778796*Experience + -34082.50023913903

# %%
x.columns
# Out:
# Index(['Age', 'Experience'], dtype='object')

# %%
lr.predict(x_test)
# Out:
# array([120234.66293344,  66405.85348745, 100036.26899163,  73071.50267039,
#         52873.10872858,  59639.48110801])
